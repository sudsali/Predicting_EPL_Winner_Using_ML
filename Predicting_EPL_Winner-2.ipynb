# %%
#importing necessary Libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from xgboost import XGBClassifier

# %%
#Fetching the dataset
matches = pd.read_csv('/content/matches_data.csv',index_col = 0)

# %%
#Dsipalying the first 5 rows of the dataframe
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#    season             team
# 1    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 5    2023  Manchester City
# 6    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
#Displaying the shape of the dataframe
matches.shape
# Out:
# (3800, 27)

# %%
#Counting total number of matches per team
matches["team"].value_counts()
# Out:
# team
# Manchester City             190
# Manchester United           190
# Everton                     190
# Arsenal                     190
# Brighton and Hove Albion    190
# Crystal Palace              190
# West Ham United             190
# Wolverhampton Wanderers     190
# Newcastle United            190
# Tottenham Hotspur           190
# Aston Villa                 190
# Liverpool                   190
# Chelsea                     190
# Burnley                     152
# Leicester City              152
# Southampton                 152
# Bournemouth                 114
# Fulham                      114
# Brentford                   114
# Sheffield United            114
# Leeds United                114
# Norwich City                 76
# Nottingham Forest            76
# Watford                      76
# Luton Town                   38
# West Bromwich Albion         38
# Name: count, dtype: int64

# %%
#Counting total number of matches per round
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     100
# Matchweek 30    100
# Matchweek 23    100
# Matchweek 24    100
# Matchweek 25    100
# Matchweek 18    100
# Matchweek 26    100
# Matchweek 27    100
# Matchweek 28    100
# Matchweek 31    100
# Matchweek 2     100
# Matchweek 32    100
# Matchweek 33    100
# Matchweek 29    100
# Matchweek 35    100
# Matchweek 36    100
# Matchweek 37    100
# Matchweek 34    100
# Matchweek 22    100
# Matchweek 21    100
# Matchweek 20    100
# Matchweek 19    100
# Matchweek 3     100
# Matchweek 4     100
# Matchweek 5     100
# Matchweek 6     100
# Matchweek 7     100
# Matchweek 8     100
# Matchweek 9     100
# Matchweek 10    100
# Matchweek 11    100
# Matchweek 12    100
# Matchweek 13    100
# Matchweek 14    100
# Matchweek 15    100
# Matchweek 16    100
# Matchweek 17    100
# Matchweek 38    100
# Name: count, dtype: int64

# %%
#Displaying the datatypes
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
#Converting the date column into datetime datatype
matches["date"] = pd.to_datetime(matches["date"])

# %%
#Converting the venues into categorical data represented as integers
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
#Converting the opponents into categorical data represented as integers
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#Remove the colon and minutes from the hour and store the hour as an int
matches["hour"] = matches["time"].str.replace(":.+","",regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#Creating a target column
def result_to_target(result):
    if result == 'W':
        return 1
    else:
        return 0

# Apply the function to the 'result' column
matches['target'] = matches['result'].apply(result_to_target)

# %%
#Initialize the randomclassifier classifier
rf = RandomForestClassifier(n_estimators= 100, min_samples_split=10, random_state=42)

# %%
#Splitting our data into train and test set
train = matches[matches["date"] < "2023 - 08 - 01"]
test = matches[matches["date"] > "2023 - 08 - 01"]

# %%
#Shape of training dataset
train.shape
# Out:
# (3040, 32)

# %%
#Shape of test dataset
test.shape
# Out:
# (760, 32)

# %%
#Setting our predictors
predictors = ["venue_code","opp_code","hour","day_code"]

# %%
#Fitting the model
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, random_state=42)

# %%
#Testing our model
preds = rf.predict(test[predictors])

# %%
#Calculating the accuracy of the model
acc = accuracy_score(test["target"],preds)
print("Acuuracy of the model:",acc)
# Out:
# Acuuracy of the model: 0.6039473684210527

# %%
combined = pd.DataFrame(dict(actual = test["target"],prediction = preds))

# %%
pd.crosstab(index=combined["actual"],columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           370  92
# 1           209  89

# %%
#Calculating precision score using average as macro since it is a multi class classfication problem
precision = precision_score(test['target'], preds, average='macro')
print(f"Macro-average Precision: {precision:.2f}")
# Out:
# Macro-average Precision: 0.57

# %%
#Creating more predictors to improve accuracy
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester United")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2023-08-14  20:00  Premier League   Matchweek 1  Mon  Home      W   1   0
# 1  2023-08-19  17:30  Premier League   Matchweek 2  Sat  Away      L   0   2
# 2  2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      W   3   2
# 3  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Away      L   1   3
# 4  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Home      L   1   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2020-07-09  20:15  Premier League  Matchweek 34  Thu  Away      W   3   0
# 53 2020-07-13  20:00  Premier League  Matchweek 35  Mon  Home      D   2   2
# 54 2020-07-16  20:15  Premier League  Matchweek 36  Thu  Away      W   2   0
# 56 2020-07-22  18:00  Premier League  Matchweek 37  Wed  Home      D   1   1
# 57 2020-07-26  16:00  Premier League  Matchweek 38  Sun  Away      W   2   0
#
#            opponent  ...   fk  pk  pkatt  season               team  \
# 0            Wolves  ...  0.0   0      0    2023  Manchester United
# 1         Tottenham  ...  1.0   0      0    2023  Manchester United
# 2   Nott'ham Forest  ...  0.0   1      1    2023  Manchester United
# 3           Arsenal  ...  0.0   0      0    2023  Manchester United
# 4          Brighton  ...  1.0   0      0    2023  Manchester United
# ..              ...  ...  ...  ..    ...     ...                ...
# 52      Aston Villa  ...  1.0   1      1    2019  Manchester United
# 53      Southampton  ...  0.0   0      0    2019  Manchester United
# 54   Crystal Palace  ...  1.0   0      0    2019  Manchester United
# 56         West Ham  ...  0.0   0      0    2019  Manchester United
# 57   Leicester City  ...  0.0   1      1    2019  Manchester United
#
#    venue_code opp_code hour  day_code  target
# 0           1       25   20         0       1
# 1           0       21   17         5       0
# 2           1       18   15         5       1
# 3           0        0   16         6       0
# 4           1        4   15         5       0
# ..        ...      ...  ...       ...     ...
# 52          0        1   20         3       1
# 53          1       20   20         0       0
# 54          0        7   20         3       1
# 56          1       24   18         2       0
# 57          0       11   16         6       1
#
# [190 rows x 32 columns]

# %%
#Creating a fucntion to compute rolling averages
def rolling_average(group,cols,new_cols):
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(3,closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
#Creating cols and new_cols variables
cols = ["gf","ga","sh","sot","dist","fk","pk","pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
#Compute rolling averages for every team
matches_rolling = matches.groupby("team").apply(lambda x: rolling_average(x,cols,new_cols))
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2019-09-01  16:30  Premier League   Matchweek 4
#                         4  2019-09-15  16:30  Premier League   Matchweek 5
#                         6  2019-09-22  16:30  Premier League   Matchweek 6
#                         8  2019-09-30  20:00  Premier League   Matchweek 7
#                         10 2019-10-06  14:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 40 2024-04-24  19:45  Premier League  Matchweek 29
#                         41 2024-04-27  15:00  Premier League  Matchweek 35
#                         42 2024-05-04  17:30  Premier League  Matchweek 36
#                         43 2024-05-11  15:00  Premier League  Matchweek 37
#                         44 2024-05-19  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 3   Sun  Home      D   2   2        Tottenham  ...
#                         4   Sun  Away      D   2   2          Watford  ...
#                         6   Sun  Home      W   3   2      Aston Villa  ...
#                         8   Mon  Away      D   1   1   Manchester Utd  ...
#                         10  Sun  Home      W   1   0      Bournemouth  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 40  Wed  Home      L   0   1      Bournemouth  ...
#                         41  Sat  Home      W   2   1       Luton Town  ...
#                         42  Sat  Away      L   1   5  Manchester City  ...
#                         43  Sat  Home      L   1   3   Crystal Palace  ...
#                         44  Sun  Away      L   0   2        Liverpool  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 3          6       0    1.333333    1.333333
#                         4          6       0    1.666667    2.000000
#                         6          6       1    1.666667    2.333333
#                         8          0       0    2.333333    2.000000
#                         10         6       1    2.000000    1.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 40         2       0    1.000000    2.000000
#                         41         5       1    0.666667    1.666667
#                         42         5       0    0.666667    1.333333
#                         43         5       0    1.000000    2.333333
#                         44         6       0    1.333333    3.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 3   10.666667    4.666667    17.200000   0.333333
#                         4   16.666667    6.666667    18.600000   1.000000
#                         6   14.000000    5.000000    19.300000   1.000000
#                         8   17.666667    5.666667    18.600000   1.333333
#                         10  12.333333    4.666667    18.100000   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 40   9.666667    4.000000    20.533333   0.333333
#                         41  10.333333    3.333333    18.766667   0.000000
#                         42  11.000000    4.000000    19.666667   0.000000
#                         43  10.000000    3.333333    15.966667   0.000000
#                         44   9.666667    4.666667    14.133333   0.000000
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 3     0.000000       0.000000
#                         4     0.000000       0.000000
#                         6     0.000000       0.000000
#                         8     0.333333       0.333333
#                         10    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 40    0.333333       0.333333
#                         41    0.000000       0.000000
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#                         44    0.000000       0.000000
#
# [3719 rows x 40 columns]

# %%
#Dropping the extra index level
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 3  2019-09-01  16:30  Premier League   Matchweek 4  Sun  Home      D   2   2
# 4  2019-09-15  16:30  Premier League   Matchweek 5  Sun  Away      D   2   2
# 6  2019-09-22  16:30  Premier League   Matchweek 6  Sun  Home      W   3   2
# 8  2019-09-30  20:00  Premier League   Matchweek 7  Mon  Away      D   1   1
# 10 2019-10-06  14:00  Premier League   Matchweek 8  Sun  Home      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 40 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0   1
# 41 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 42 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1   5
# 43 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1   3
# 44 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 3         Tottenham  ...         6       0    1.333333    1.333333  10.666667
# 4           Watford  ...         6       0    1.666667    2.000000  16.666667
# 6       Aston Villa  ...         6       1    1.666667    2.333333  14.000000
# 8    Manchester Utd  ...         0       0    2.333333    2.000000  17.666667
# 10      Bournemouth  ...         6       1    2.000000    1.666667  12.333333
# ..              ...  ...       ...     ...         ...         ...        ...
# 40      Bournemouth  ...         2       0    1.000000    2.000000   9.666667
# 41       Luton Town  ...         5       1    0.666667    1.666667  10.333333
# 42  Manchester City  ...         5       0    0.666667    1.333333  11.000000
# 43   Crystal Palace  ...         5       0    1.000000    2.333333  10.000000
# 44        Liverpool  ...         6       0    1.333333    3.000000   9.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3     4.666667    17.200000   0.333333    0.000000       0.000000
# 4     6.666667    18.600000   1.000000    0.000000       0.000000
# 6     5.000000    19.300000   1.000000    0.000000       0.000000
# 8     5.666667    18.600000   1.333333    0.333333       0.333333
# 10    4.666667    18.100000   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 40    4.000000    20.533333   0.333333    0.333333       0.333333
# 41    3.333333    18.766667   0.000000    0.000000       0.000000
# 42    4.000000    19.666667   0.000000    0.000000       0.000000
# 43    3.333333    15.966667   0.000000    0.000000       0.000000
# 44    4.666667    14.133333   0.000000    0.000000       0.000000
#
# [3719 rows x 40 columns]

# %%
#Making sure the index is unique
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2019-09-01  16:30  Premier League   Matchweek 4  Sun  Home      D   2
# 1    2019-09-15  16:30  Premier League   Matchweek 5  Sun  Away      D   2
# 2    2019-09-22  16:30  Premier League   Matchweek 6  Sun  Home      W   3
# 3    2019-09-30  20:00  Premier League   Matchweek 7  Mon  Away      D   1
# 4    2019-10-06  14:00  Premier League   Matchweek 8  Sun  Home      W   1
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 3714 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0
# 3715 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2
# 3716 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1
# 3717 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1
# 3718 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0
#
#       ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0      2        Tottenham  ...         6       0    1.333333    1.333333
# 1      2          Watford  ...         6       0    1.666667    2.000000
# 2      2      Aston Villa  ...         6       1    1.666667    2.333333
# 3      1   Manchester Utd  ...         0       0    2.333333    2.000000
# 4      0      Bournemouth  ...         6       1    2.000000    1.666667
# ...   ..              ...  ...       ...     ...         ...         ...
# 3714   1      Bournemouth  ...         2       0    1.000000    2.000000
# 3715   1       Luton Town  ...         5       1    0.666667    1.666667
# 3716   5  Manchester City  ...         5       0    0.666667    1.333333
# 3717   3   Crystal Palace  ...         5       0    1.000000    2.333333
# 3718   2        Liverpool  ...         6       0    1.333333    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0     10.666667    4.666667    17.200000   0.333333    0.000000       0.000000
# 1     16.666667    6.666667    18.600000   1.000000    0.000000       0.000000
# 2     14.000000    5.000000    19.300000   1.000000    0.000000       0.000000
# 3     17.666667    5.666667    18.600000   1.333333    0.333333       0.333333
# 4     12.333333    4.666667    18.100000   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 3714   9.666667    4.000000    20.533333   0.333333    0.333333       0.333333
# 3715  10.333333    3.333333    18.766667   0.000000    0.000000       0.000000
# 3716  11.000000    4.000000    19.666667   0.000000    0.000000       0.000000
# 3717  10.000000    3.333333    15.966667   0.000000    0.000000       0.000000
# 3718   9.666667    4.666667    14.133333   0.000000    0.000000       0.000000
#
# [3719 rows x 40 columns]

# %%
#Function for retraining the model
def make_predictions(data,predictors):
  train = data[data["date"] < "2023 - 08 - 01"]
  test = data[data["date"] > "2023 - 08 - 01"]
  rf.fit(train[predictors],train["target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual = test["target"],prediction = preds),index = test.index)
  precision = precision_score(test['target'], preds, average='macro')
  accuracy = accuracy_score(test['target'],preds)
  return combined,precision,accuracy

# %%
#Calculating the precision of the new model
combined,precision,accuracy = make_predictions(matches_rolling,predictors + new_cols)

# %%
#Displaying the new precision score
precision
# Out:
# 0.6215013064175525

# %%
#Displaying the accuracy of the new model
accuracy
# Out:
# 0.6446499339498019

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
#Mapping team names
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves","West Bromwich Albion":"West Brom","Nottingham Forest":"Nott'ham Forest",}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined['team'].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           1             1 2023-08-12                  Arsenal
# 1           1             0 2023-08-21                  Arsenal
# 2           0             1 2023-08-26                  Arsenal
# 3           1             1 2023-09-03                  Arsenal
# 4           1             1 2023-09-17                  Arsenal
# ..        ...           ...        ...                      ...
# 711         0             0 2024-04-24  Wolverhampton Wanderers
# 712         1             0 2024-04-27  Wolverhampton Wanderers
# 713         0             0 2024-05-04  Wolverhampton Wanderers
# 714         0             0 2024-05-11  Wolverhampton Wanderers
# 715         0             0 2024-05-19  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0    Nott'ham Forest        W    Arsenal         0             0
# 1     Crystal Palace        W    Arsenal         0             0
# 2             Fulham        D    Arsenal         0             0
# 3     Manchester Utd        W    Arsenal         0             0
# 4            Everton        W    Arsenal         0             0
# ..               ...      ...        ...       ...           ...
# 711      Bournemouth        L     Wolves         1             0
# 712       Luton Town        W     Wolves         0             0
# 713  Manchester City        L     Wolves         1             1
# 714   Crystal Palace        L     Wolves         1             0
# 715        Liverpool        L     Wolves         1             1
#
#                 team_y opponent_y result_y       new_team_y
# 0    Nottingham Forest    Arsenal        L  Nott'ham Forest
# 1       Crystal Palace    Arsenal        L   Crystal Palace
# 2               Fulham    Arsenal        D           Fulham
# 3    Manchester United    Arsenal        L   Manchester Utd
# 4              Everton    Arsenal        L          Everton
# ..                 ...        ...      ...              ...
# 711        Bournemouth     Wolves        W      Bournemouth
# 712         Luton Town     Wolves        L       Luton Town
# 713    Manchester City     Wolves        W  Manchester City
# 714     Crystal Palace     Wolves        W   Crystal Palace
# 715          Liverpool     Wolves        W        Liverpool
#
# [716 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    104
# 0     68
# Name: count, dtype: int64
